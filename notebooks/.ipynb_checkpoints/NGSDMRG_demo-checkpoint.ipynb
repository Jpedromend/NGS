# %% [markdown]
# # NGS-DMRG: Variational non-Gaussian solutions to interacting spin-boson models
#
# NGS-DMRG is a hybrid numerical framework for simulating the ground-state properties of strongly correlated spin-boson systems.

# %% [markdown]
# Here we show the implementation of the method described in:
# > <ins>Role of Matter Interactions in Superradiant Phenomena</ins>,
# > JP Mendonça, K Jachymski, Y Wang,
# > _Physical Review Letters_ 135 (**13**), 133601 (2025)
#
# using the Dicke model as an example.

# %% [markdown]
# The necessary packages for this demo are:

# %%
using ITensors, ITensorMPS, Optim, LinearAlgebra

# %% [markdown]
# The Dicke model is given by
# $$
# \begin{aligned}
# H &= \omega a^\dagger a + \varepsilon \sum_j s^z_j + \frac{2g}{\sqrt{N}} \sum_j s^x_j (a + a^\dagger ) \\
# &= \frac{\omega}{2} (x^2 + p^2) + \varepsilon S^z + g' S^x x
# \end{aligned}
# $$
# where we have dropped constant energy shifts and defined the collective spin operators $S^\alpha = \sum_j s^\alpha_j$, the photon quadratures $x = (a^\dagger + a)/\sqrt{2}$ and $p = i(a^\dagger - a)/\sqrt{2}$, and the scaled coupling $g' = 2g/\sqrt{N/2}$.

# %% [markdown]
# and we choose the following model parameters

# %%
N = 20 # number of atoms
omega = 1.0 # cavity frequency
eps = 1.0 # atomic splitting
g = 0.8 # atom-cavity coupling strength
# Out:
# 0.8

# %% [markdown]
# This framework combines:
# 1.  **Non-Gaussian Variational Ansatz:**
#
# $$|\psi_{\rm NGS}\rangle = U_{\lambda} \left( U_{\mathrm{GS}} |0\rangle_{\rm b}\otimes|\phi\rangle_{\rm s} \right).$$
#
# The bosonic sector is treated using a variational manifold combining displacement and squeezing, forming a Gaussian state. A (Lang-Firsov-inspired) polariton dressing transformation introduces entanglement between the two subsystems. This replaces explicit Hilbert space/photon number truncation.
#
# In this notebook, we fix the above ansatz to a simplified form that has shown to be very efficient to (extended) Dicke models:
# $$|\psi_{\rm NGS}\rangle = \exp\left(i \lambda \frac{g'}{\omega} S^x p\right) \exp(-i\Delta_x p) \exp\left(-\frac{i}{2}\xi (xp+px)\right) |0\rangle_{\rm b} \otimes |\phi\rangle_{\rm s} .$$
#
# 2.  **Tensor Network Solver:** The many-body spin state $|\phi\rangle_{\rm s}$ is obtained, with no further approximations, solving the effective spin Hamiltonian
#
# $$H_{\rm eff} = \langle \psi_{\rm b} | U_\lambda^\dagger H U_\lambda | \psi_{\rm b} \rangle,$$
#
# using Density Matrix Renormalization Group (DMRG) via `ITensors.jl` and `ITensorMPS.jl`, capturing spin-spin correlations.
#
# 3. **Self-Consistent optimization:**
#
# A self-consistent optimization loop then minimizes the variational energy with respect to both the variational parameters and the spin wavefunction, ultimately combining the two steps above.
#
# An accurate approximation of the full spin-boson ground state beyond mean-field theory, i.e., beyond the factorized approximation, is obtained.

# %% [markdown]
# # Important Definitions

# %%
# Define the ITensor site types
sites = siteinds("S=1/2", N)
# Out:
# 20-element Vector{Index{Int64}}:
#  (dim=2|id=184|"S=1/2,Site,n=1")
#  (dim=2|id=933|"S=1/2,Site,n=2")
#  (dim=2|id=418|"S=1/2,Site,n=3")
#  (dim=2|id=759|"S=1/2,Site,n=4")
#  (dim=2|id=975|"S=1/2,Site,n=5")
#  (dim=2|id=698|"S=1/2,Site,n=6")
#  (dim=2|id=556|"S=1/2,Site,n=7")
#  (dim=2|id=448|"S=1/2,Site,n=8")
#  (dim=2|id=345|"S=1/2,Site,n=9")
#  (dim=2|id=760|"S=1/2,Site,n=10")
#  (dim=2|id=804|"S=1/2,Site,n=11")
#  (dim=2|id=514|"S=1/2,Site,n=12")
#  (dim=2|id=841|"S=1/2,Site,n=13")
#  (dim=2|id=670|"S=1/2,Site,n=14")
#  (dim=2|id=641|"S=1/2,Site,n=15")
#  (dim=2|id=217|"S=1/2,Site,n=16")
#  (dim=2|id=61|"S=1/2,Site,n=17")
#  (dim=2|id=482|"S=1/2,Site,n=18")
#  (dim=2|id=768|"S=1/2,Site,n=19")
#  (dim=2|id=928|"S=1/2,Site,n=20")

# %% [markdown]
# ## Define Spin Operators as MPO

# %%
# Define the spin operators to define the effective Hamiltonian
sz_op = OpSum()
sx_op = OpSum()
sx2_op = OpSum()

for j in 1:N
    sx_op += "Sx", j
    sz_op += "Sz", j
    for k in 1:N
        sx2_op += "Sx", j, "Sx", k
    end
end

Sz = MPO(sz_op, sites)
Sx = MPO(sx_op, sites)
Sx2 = MPO(sx2_op, sites)
# Out:
# MPO
# [1] ((dim=3|id=213|"Link,l=1"), (dim=2|id=184|"S=1/2,Site,n=1")', (dim=2|id=184|"S=1/2,Site,n=1"))
# [2] ((dim=3|id=213|"Link,l=1"), (dim=3|id=454|"Link,l=2"), (dim=2|id=933|"S=1/2,Site,n=2")', (dim=2|id=933|"S=1/2,Site,n=2"))
# [3] ((dim=3|id=454|"Link,l=2"), (dim=3|id=605|"Link,l=3"), (dim=2|id=418|"S=1/2,Site,n=3")', (dim=2|id=418|"S=1/2,Site,n=3"))
# [4] ((dim=3|id=605|"Link,l=3"), (dim=3|id=345|"Link,l=4"), (dim=2|id=759|"S=1/2,Site,n=4")', (dim=2|id=759|"S=1/2,Site,n=4"))
# [5] ((dim=3|id=345|"Link,l=4"), (dim=3|id=363|"Link,l=5"), (dim=2|id=975|"S=1/2,Site,n=5")', (dim=2|id=975|"S=1/2,Site,n=5"))
# [6] ((dim=3|id=363|"Link,l=5"), (dim=3|id=717|"Link,l=6"), (dim=2|id=698|"S=1/2,Site,n=6")', (dim=2|id=698|"S=1/2,Site,n=6"))
# [7] ((dim=3|id=717|"Link,l=6"), (dim=3|id=449|"Link,l=7"), (dim=2|id=556|"S=1/2,Site,n=7")', (dim=2|id=556|"S=1/2,Site,n=7"))
# [8] ((dim=3|id=449|"Link,l=7"), (dim=3|id=49|"Link,l=8"), (dim=2|id=448|"S=1/2,Site,n=8")', (dim=2|id=448|"S=1/2,Site,n=8"))
# [9] ((dim=3|id=49|"Link,l=8"), (dim=3|id=944|"Link,l=9"), (dim=2|id=345|"S=1/2,Site,n=9")', (dim=2|id=345|"S=1/2,Site,n=9"))
# [10] ((dim=3|id=944|"Link,l=9"), (dim=3|id=878|"Link,l=10"), (dim=2|id=760|"S=1/2,Site,n=10")', (dim=2|id=760|"S=1/2,Site,n=10"))
# [11] ((dim=3|id=878|"Link,l=10"), (dim=3|id=332|"Link,l=11"), (dim=2|id=804|"S=1/2,Site,n=11")', (dim=2|id=804|"S=1/2,Site,n=11"))
# [12] ((dim=3|id=332|"Link,l=11"), (dim=3|id=344|"Link,l=12"), (dim=2|id=514|"S=1/2,Site,n=12")', (dim=2|id=514|"S=1/2,Site,n=12"))
# [13] ((dim=3|id=344|"Link,l=12"), (dim=3|id=583|"Link,l=13"), (dim=2|id=841|"S=1/2,Site,n=13")', (dim=2|id=841|"S=1/2,Site,n=13"))
# [14] ((dim=3|id=583|"Link,l=13"), (dim=3|id=643|"Link,l=14"), (dim=2|id=670|"S=1/2,Site,n=14")', (dim=2|id=670|"S=1/2,Site,n=14"))
# [15] ((dim=3|id=643|"Link,l=14"), (dim=3|id=934|"Link,l=15"), (dim=2|id=641|"S=1/2,Site,n=15")', (dim=2|id=641|"S=1/2,Site,n=15"))
# [16] ((dim=3|id=934|"Link,l=15"), (dim=3|id=190|"Link,l=16"), (dim=2|id=217|"S=1/2,Site,n=16")', (dim=2|id=217|"S=1/2,Site,n=16"))
# [17] ((dim=3|id=190|"Link,l=16"), (dim=3|id=57|"Link,l=17"), (dim=2|id=61|"S=1/2,Site,n=17")', (dim=2|id=61|"S=1/2,Site,n=17"))
# [18] ((dim=3|id=57|"Link,l=17"), (dim=3|id=708|"Link,l=18"), (dim=2|id=482|"S=1/2,Site,n=18")', (dim=2|id=482|"S=1/2,Site,n=18"))
# [19] ((dim=3|id=708|"Link,l=18"), (dim=3|id=310|"Link,l=19"), (dim=2|id=768|"S=1/2,Site,n=19")', (dim=2|id=768|"S=1/2,Site,n=19"))
# [20] ((dim=3|id=310|"Link,l=19"), (dim=2|id=928|"S=1/2,Site,n=20")', (dim=2|id=928|"S=1/2,Site,n=20"))

# %% [markdown]
# ## Define the Energy Cost
# The variational energy is exactly given by
# $$
# \mathcal{E} = \frac{\omega}{2} \Delta_x^2 + \omega \sinh^2(\xi) + \varepsilon \exp\left( - \frac{\lambda^2 g'^2}{4\omega^2} e^{-2\xi} \right) \langle S^z \rangle_{\rm s} + g'(1 - \lambda) \Delta_x \langle S^x \rangle_{\rm s} + \frac{g'^2}{2\omega} (\lambda^2 - 2\lambda) \langle (S^x)^2 \rangle_{\rm s} .
# $$
# where $\langle \cdot \rangle_{\rm s}$ represent lab-frame spin averages.
# Moreover, in this example, the variational parameter $\Delta_x$ is minimized analytically:
# $$ \Delta_x^* = -\frac{(1-\lambda)g'}{\omega} \langle S^x \rangle_{\rm s} , $$
# such that
# $$\mathcal{E} = \omega \sinh^2(\xi) + \varepsilon \exp\left( - \frac{2\lambda^2 g^2}{N\omega^2} e^{-2\xi} \right) \langle S^z \rangle_{\rm s} - \frac{4g^2}{N\omega} (1 - \lambda)^2 \langle S^x \rangle_{\rm s}^2 + \frac{4g^2}{N\omega} (\lambda^2 - 2\lambda) \langle (S^x)^2 \rangle_{\rm s} . $$
#
# In code, we define ``K=(4.0*g^2)/(N*omega)`` and ``eta = (2.0/N)*exp(-2.0*xi)*(lmd*g/omega)^2`` to simplify the equations.

# %%
# Define the variational energy cost to be minimized
function energy_cost(model_params, var_params, spin_avgs)
    omega, eps, g, N = model_params
    xi, lmd = var_params
    sz, sx, sx2 = spin_avgs

    K = (4.0*g^2)/(N*omega)
    eta = (2.0/N)*exp(-2.0*xi)*(lmd*g/omega)^2

    return omega*sinh(xi)^2 + eps*exp(-eta)*sz - K*( (1-lmd)*sx )^2 + K*(lmd^2 - 2.0*lmd)*sx2
end
# Out:
# energy_cost (generic function with 1 method)

# %%
# Define the spin averages
function spin_averages(psi)
    avg_sx = sum(expect(psi, "Sx"))
    avg_sz = sum(expect(psi, "Sz"))
    corr_sxsx = correlation_matrix(psi, "Sx", "Sx")
    avg_sx2 = sum(corr_sxsx)

    return real(avg_sz), real(avg_sx), real(avg_sx2)
end
# Out:
# spin_averages (generic function with 1 method)

# %% [markdown]
# ## Define the Effective Spin Hamiltonian
#
# The effective Hamiltonian (fixing $\Delta_x^*$ and constants dropped):
# $$H_{\rm eff} = \varepsilon \exp\left( - \frac{2\lambda^2 g^2}{N\omega^2} e^{-2\xi} \right) S^z - \frac{8g^2}{N\omega} (1 - \lambda)^2 \langle S^x \rangle S^x + \frac{4g^2}{N\omega} (\lambda^2 - 2\lambda) (S^x)^2$$

# %% [markdown]
# ## The Self-Consistent Loop

# %%
# State Initialization
psi = randomMPS(sites, 10)
xi, lmd = [rand(-0.1:0.01:0.1), rand(0.0:0.1:0.5)]
_sz,_sx,_sx2 = spin_averages(psi)
# Out:
# (0.44203515568521684, -0.35330551711620267, 4.955114300782956)

# %%
K = (4.0*g^2)/(N*omega)
# Loop Initialization
max_iter = 500
prev_E0 = Inf
E0 = 0.0
for iter in 1:max_iter
    # check convergence
    if abs(E0-prev_E0) < 1e-8
        println("converged at step $iter")
        break
    end
    println("step $iter: energy difference = $(abs(E0-prev_E0))")
    prev_E0 = E0
    
    # Built the effective spin Hamiltonian
    eta = (2.0/N)*exp(-2.0*xi)*(lmd*g/omega)^2
    H_eff = eps*exp(-eta)*Sz - 2.0*K*((1-lmd)^2)*_sx*Sx + K*(lmd^2 - 2.0*lmd)*Sx2
    
    # Run DMRG
    obs = DMRGObserver(energy_tol=1e-8, minsweeps=20)
    _, psi = dmrg(H_eff, psi; nsweeps=500, maxdim=[20,50,100,250], cutoff=[1e-8], observer=obs, outputlevel=1)

    # Update spin averages
    _sz,_sx,_sx2 = spin_averages(psi)
    
    # Optimize Variational Parameters
    cost_func(x) = energy_cost([omega, eps, g, N], x, [_sz,_sx,_sx2])
    res = optimize(cost_func, [xi,lmd], LBFGS(), Optim.Options(iterations=100))
    xi,lmd = Optim.minimizer(res)
    E0 = Optim.minimum(res)
end
# Out:
# step 1: energy difference = Inf
# After sweep 1 energy=-11.60369913882633  maxlinkdim=20 maxerr=2.84E-06 time=0.017
# After sweep 2 energy=-11.610978258667819  maxlinkdim=5 maxerr=9.45E-09 time=0.011
# After sweep 3 energy=-11.610978324976927  maxlinkdim=5 maxerr=1.03E-09 time=0.005
# After sweep 4 energy=-11.610978325278577  maxlinkdim=5 maxerr=9.46E-10 time=0.006
# After sweep 5 energy=-11.61097832529262  maxlinkdim=5 maxerr=9.43E-10 time=0.005
# After sweep
maxlinkdim=2 maxerr=6.98E-10 time=0.004
# After sweep 10 energy=-19.979085182735624  maxlinkdim=2 maxerr=6.98E-10 time=0.004
# After sweep 11 energy=-19.979085182735645  maxlinkdim=2 maxerr=6.98E-10 time=0.006
# After sweep 12 energy=-19.979085182735588  maxlinkdim=2 maxerr=6.98E-10 time=0.004
# After sweep 13 energy=-19.979085182735645  maxlinkdim=2 maxerr=6.98E-10 time=0.004
# After sweep 14 energy=-19.979085182735638  maxlinkdim=2 maxerr=6.98E-10 time=0.006
# After sweep 15 energy=-19.979085182735634  maxlinkdim=2 maxerr=6.98E-10 time=0.004
# After sweep 16 energy=-19.979085182735627  maxlinkdim=2 maxerr=6.98E-10 time=0.004
# After sweep 17 energy=-19.979085182735616  maxlinkdim=2 maxerr=6.98E-10 time=0.006
# After sweep 18 energy=-19.97908518273566  maxlinkdim=2 maxerr=6.98E-10 time=0.004
# After sweep 19 energy=-19.979085182735652  maxlinkdim=2 maxerr=6.98E-10 time=0.004
# After sweep 20 energy=-19.979085182735638  maxlinkdim=2 maxerr=6.98E-10 time=0.006
# After sweep 21 energy=-19.979085182735602  maxlinkdim=2 maxerr=6.98E-10 time=0.004
# Energy difference less than 1.0e-8, stopping DMRG
# converged at step 7

# %% [markdown]
# ## Final Converged Result
#
# The explicit equations for the expectation values in the non-Gaussian ansatz are:
#
# $$\langle n \rangle_{\rm NGS} = \sinh^2(\xi) + \frac{4g^2}{N\omega^2} (1-\lambda^2) \langle S^x \rangle^2 + \frac{4 g^2}{N\omega^2} \lambda^2 \langle (S^x)^2 \rangle$$
#
# $$\langle S^z \rangle_{\rm NGS} = \exp\left( - \frac{2\lambda^2 g^2}{N\omega^2} e^{-2\xi} \right) \langle S^z \rangle$$

# %%
# Update the coefficients and bare averages
eta = (2.0/N)*exp(-2.0*xi)*(lmd*g/omega)^2
Komg = (4.0*g^2)/(N*omega^2)
_sz,_sx,_sx2 = spin_averages(psi)

# Observables
avg_n = sinh(xi)^2 + Komg*(1-lmd^2)*_sx^2 + Komg*_sx2*lmd^2
avg_sz = exp(-eta)*_sz

println("Mean photon number: $(avg_n/N) \nMean magnetization: $(avg_sz/N)")
# Out:
# Mean photon number: 0.5384776701993021
# Mean magnetization: -0.1984577641663237

# %% [markdown]
# # Quantum Phase Transitions
#
# We now loop over $g$ to explore the QPT.

# %%
# Model Parameters
N = 100 # number of atoms
omega = 1.0 # cavity frequency
eps = 1.0 # atomic splitting

# Define the ITensor site types
sites = siteinds("S=1/2", N)

# Define the spin operators to define the effective Hamiltonian
sz_op = OpSum()
sx_op = OpSum()
sx2_op = OpSum()

for j in 1:N
    sx_op += "Sx", j
    sz_op += "Sz", j
    for k in 1:N
        sx2_op += "Sx", j, "Sx", k
    end
end

Sz = MPO(sz_op, sites)
Sx = MPO(sx_op, sites)
Sx2 = MPO(sx2_op, sites)
# Out:
# MPO
# [1] ((dim=3|id=102|"Link,l=1"), (dim=2|id=784|"S=1/2,Site,n=1")', (dim=2|id=784|"S=1/2,Site,n=1"))
# [2] ((dim=3|id=102|"Link,l=1"), (dim=3|id=758|"Link,l=2"), (dim=2|id=216|"S=1/2,Site,n=2")', (dim=2|id=216|"S=1/2,Site,n=2"))
# [3] ((dim=3|id=758|"Link,l=2"), (dim=3|id=682|"Link,l=3"), (dim=2|id=878|"S=1/2,Site,n=3")', (dim=2|id=878|"S=1/2,Site,n=3"))
# [4] ((dim=3|id=682|"Link,l=3"), (dim=3|id=701|"Link,l=4"), (dim=2|id=96|"S=1/2,Site,n=4")', (dim=2|id=96|"S=1/2,Site,n=4"))
# [5] ((dim=3|id=701|"Link,l=4"), (dim=3|id=29|"Link,l=5"), (dim=2|id=837|"S=1/2,Site,n=5")', (dim=2|id=837|"S=1/2,Site,n=5"))
# [6] ((dim=3|id=29|"Link,l=5"), (dim=3|id=637|"Link,l=6"), (dim=2|id=591|"S=1/2,Site,n=6")', (dim=2|id=591|"S=1/2,Site,n=6"))
# [7] ((dim=3|id=637|"Link,l=6"), (dim=3|id=111|"Link,l=7"), (dim=2|id=978|"S=1/2,Site,n=7")', (dim=2|id=978|"S=1/2,Site,n=7"))
# [8] ((dim=3|id=111|"Link,l=7"), (dim=3|id=683|"Link,l=8"), (dim=2|id=8|"S=1/2,Site,n=8")', (dim=2|id=8|"S=1/2,Site,n=8"))
# [9] ((dim=3|id=683|"Link,l=8"), (dim=3|id=545|"Link,l=9"), (dim=2|id=82|"S=1/2,Site,n=9")', (dim=2|id=82|"S=1/2,Site,n=9"))
# [10] ((dim=3|id=545|"Link,l=9"), (dim=3|id=84|"Link,l=10"), (dim=2|id=44|"S=1/2,Site,n=10")', (dim=2|id=44|"S=1/2,Site,n=10"))
# [11] ((dim=3|id=84|"Link,l=10"), (dim=3|id=857|"Link,l=11"), (dim=2|id=973|"S=1/2,Site,n=11")', (dim=2|id=973|"S=1/2,Site,n=11"))
# [12] ((dim=3|id=857|"Link,l=11"), (dim=3|id=521|"Link,l=12"), (dim=2|id=782|"S=1/2,Site,n=12")', (dim=2|id=782|"S=1/2,Site,n=12"))
# [13] ((dim=3|id=521|"Link,l=12"), (dim=3|id=163|"Link,l=13"), (dim=2|id=26|"S=1/2,Site,n=13")', (dim=2|id=26|"S=1/2,Site,n=13"))
# [14] ((dim=3|id=163|"Link,l=13"), (dim=3|id=201|"Link,l=14"), (dim=2|id=282|"S=1/2,Site,n=14")', (dim=2|id=282|"S=1/2,Site,n=14"))
# [15] ((dim=3|id=201|"Link,l=14"), (dim=3|id=609|"Link,l=15"), (dim=2|id=806|"S=1/2,Site,n=15")', (dim=2|id=806|"S=1/2,Site,n=15"))
# [16] ((dim=3|id=609|"Link,l=15"), (dim=3|id=681|"Link,l=16"), (dim=2|id=701|"S=1/2,Site,n=16")', (dim=2|id=701|"S=1/2,Site,n=16"))
# [17] ((dim=3|id=681|"Link,l=16"), (dim=3|id=562|"Link,l=17"), (dim=2|id=667|"S=1/2,Site,n=17")', (dim=2|id=667|"S=1/2,Site,n=17"))
# [18] ((dim=3|id=562|"Link,l=17"), (dim=3|id=447|"Link,l=18"), (dim=2|id=535|"S=1/2,Site,n=18")', (dim=2|id=535|"S=1/2,Site,n=18"))
# [19] ((dim=3|id=447|"Link,l=18"), (dim=3|id=700|"Link,l=19"), (dim=2|id=818|"S=1/2,Site,n=19")', (dim=2|id=818|"S=1/2,Site,n=19"))
# [20] ((dim=3|id=700|"Link,l=19"), (dim=3|id=55|"Link,l=20"), (dim=2|id=981|"S=1/2,Site,n=20")', (dim=2|id=981|"S=1/2,Site,n=20"))
# [21] ((dim=3|id=55|"Link,l=20"), (dim=3|id=240|"Link,l=21"), (dim=2|id=150|"S=1/2,Site,n=21")', (dim=2|id=150|"S=1/2,Site,n=21"))
# [22] ((dim=3|id=240|"Link,l=21"), (dim=3|id=599|"Link,l=22"), (dim=2|id=536|"S=1/2,Site,n=22")', (dim=2|id=536|"S=1/2,Site,n=22"))
# [23] ((dim=3|id=599|"Link,l=22"), (dim=3|id=53|"Link,l=23"), (dim=2|id=18|"S=1/2,Site,n=23")', (dim=2|id=18|"S=1/2,Site,n=23"))
# [24] ((dim=3|id=53|"Link,l=23"), (dim=3|id=140|"Link,l=24"), (dim=2|id=757|"S=1/2,Site,n=24")', (dim=2|id=757|"S=1/2,Site,n=24"))
# [25] ((dim=3|id=140|"Link,l=24"), (dim=3|id=285|"Link,l=25"), (dim=2|id=20|"S=1/2,Site,n=25")', (dim=2|id=20|"S=1/2,Site,n=25"))
# [26] ((dim=3|id=285|"Link,l=25"), (dim=3|id=977|"Link,l=26"), (dim=2|id=291|"S=1/2,Site,n=26")', (dim=2|id=291|"S=1/2,Site,n=26"))
# [27] ((dim=3|id=977|"Link,l=26"), (dim=3|id=772|"Link,l=27"), (dim=2|id=20|"S=1/2,Site,n=27")', (dim=2|id=20|"S=1/2,Site,n=27"))
# [28] ((dim=3|id=772|"Link,l=27"), (dim=3|id=355|"Link,l=28"), (dim=2|id=923|"S=1/2,Site,n=28")', (dim=2|id=923|"S=1/2,Site,n=28"))
# [29] ((dim=3|id=355|"Link,l=28"), (dim=3|id=170|"Link,l=29"), (dim=2|id=715|"S=1/2,Site,n=29")', (dim=2|id=715|"S=1/2,Site,n=29"))
# [30] ((dim=3|id=170|"Link,l=29"), (dim=3|id=13|"Link,l=30"), (dim=2|id=184|"S=1/2,Site,n=30")', (dim=2|id=184|"S=1/2,Site,n=30"))
# [31] ((dim=3|id=13|"Link,l=30"), (dim=3|id=622|"Link,l=31"), (dim=2|id=269|"S=1/2,Site,n=31")', (dim=2|id=269|"S=1/2,Site,n=31"))
# [32] ((dim=3|id=622|"Link,l=31"), (dim=3|id=161|"Link,l=32"), (dim=2|id=457|"S=1/2,Site,n=32")', (dim=2|id=457|"S=1/2,Site,n=32"))
# [33] ((dim=3|id=161|"Link,l=32"), (dim=3|id=335|"Link,l=33"), (dim=2|id=408|"S=1/2,Site,n=33")', (dim=2|id=408|"S=1/2,Site,n=33"))
# [34] ((dim=3|id=335|"Link,l=33"), (dim=3|id=158|"Link,l=34"), (dim=2|id=45|"S=1/2,Site,n=34")', (dim=2|id=45|"S=1/2,Site,n=34"))
# [35] ((dim=3|id=158|"Link,l=34"), (dim=3|id=228|"Link,l=35"), (dim=2|id=581|"S=1/2,Site,n=35")', (dim=2|id=581|"S=1/2,Site,n=35"))
# [36] ((dim=3|id=228|"Link,l=35"), (dim=3|id=226|"Link,l=36"), (dim=2|id=946|"S=1/2,Site,n=36")', (dim=2|id=946|"S=1/2,Site,n=36"))
# [37] ((dim=3|id=226|"Link,l=36"), (dim=3|id=257|"Link,l=37"), (dim=2|id=438|"S=1/2,Site,n=37")', (dim=2|id=438|"S=1/2,Site,n=37"))
# [38] ((dim=3|id=257|"Link,l=37"), (dim=3|id=763|"Link,l=38"), (dim=2|id=986|"S=1/2,Site,n=38")', (dim=2|id=986|"S=1/2,Site,n=38"))
# [39] ((dim=3|id=763|"Link,l=38"), (dim=3|id=733|"Link,l=39"), (dim=2|id=595|"S=1/2,Site,n=39")', (dim=2|id=595|"S=1/2,Site,n=39"))
# [40] ((dim=3|id=733|"Link,l=39"), (dim=3|id=161|"Link,l=40"), (dim=2|id=161|"S=1/2,Site,n=40")', (dim=2|id=161|"S=1/2,Site,n=40"))
# [41] ((dim=3|id=161|"Link,l=40"), (dim=3|id=669|"Link,l=41"), (dim=2|id=275|"S=1/2,Site,n=41")', (dim=2|id=275|"S=1/2,Site,n=41"))
# [42] ((dim=3|id=669|"Link,l=41"), (dim=3|id=383|"Link,l=42"), (dim=2|id=222|"S=1/2,Site,n=42")', (dim=2|id=222|"S=1/2,Site,n=42"))
# [43] ((dim=3|id=383|"Link,l=42"), (dim=3|id=514|"Link,l=43"), (dim=2|id=789|"S=1/2,Site,n=43")', (dim=2|id=789|"S=1/2,Site,n=43"))
# [44] ((dim=3|id=514|"Link,l=43"), (dim=3|id=129|"Link,l=44"), (dim=2|id=328|"S=1/2,Site,n=44")', (dim=2|id=328|"S=1/2,Site,n=44"))
# [45] ((dim=3|id=129|"Link,l=44"), (dim=3|id=700|"Link,l=45"), (dim=2|id=376|"S=1/2,Site,n=45")', (dim=2|id=376|"S=1/2,Site,n=45"))
# [46] ((dim=3|id=700|"Link,l=45"), (dim=3|id=473|"Link,l=46"), (dim=2|id=902|"S=1/2,Site,n=46")', (dim=2|id=902|"S=1/2,Site,n=46"))
# [47] ((dim=3|id=473|"Link,l=46"), (dim=3|id=418|"Link,l=47"), (dim=2|id=31|"S=1/2,Site,n=47")', (dim=2|id=31|"S=1/2,Site,n=47"))
# [48] ((dim=3|id=418|"Link,l=47"), (dim=3|id=503|"Link,l=48"), (dim=2|id=664|"S=1/2,Site,n=48")', (dim=2|id=664|"S=1/2,Site,n=48"))
# [49] ((dim=3|id=503|"Link,l=48"), (dim=3|id=264|"Link,l=49"), (dim=2|id=343|"S=1/2,Site,n=49")', (dim=2|id=343|"S=1/2,Site,n=49"))
# [50] ((dim=3|id=264|"Link,l=49"), (dim=3|id=471|"Link,l=50"), (dim=2|id=583|"S=1/2,Site,n=50")', (dim=2|id=583|"S=1/2,Site,n=50"))
# [51] ((dim=3|id=471|"Link,l=50"), (dim=3|id=565|"Link,l=51"), (dim=2|id=391|"S=1/2,Site,n=51")', (dim=2|id=391|"S=1/2,Site,n=51"))
# [52] ((dim=3|id=565|"Link,l=51"), (dim=3|id=90|"Link,l=52"), (dim=2|id=918|"S=1/2,Site,n=52")', (dim=2|id=918|"S=1/2,Site,n=52"))
# [53] ((dim=3|id=90|"Link,l=52"), (dim=3|id=750|"Link,l=53"), (dim=2|id=565|"S=1/2,Site,n=53")', (dim=2|id=565|"S=1/2,Site,n=53"))
# [54] ((dim=3|id=750|"Link,l=53"), (dim=3|id=995|"Link,l=54"), (dim=2|id=121|"S=1/2,Site,n=54")', (dim=2|id=121|"S=1/2,Site,n=54"))
# [55] ((dim=3|id=995|"Link,l=54"), (dim=3|id=120|"Link,l=55"), (dim=2|id=812|"S=1/2,Site,n=55")', (dim=2|id=812|"S=1/2,Site,n=55"))
# [56] ((dim=3|id=120|"Link,l=55"), (dim=3|id=729|"Link,l=56"), (dim=2|id=259|"S=1/2,Site,n=56")', (dim=2|id=259|"S=1/2,Site,n=56"))
# [57] ((dim=3|id=729|"Link,l=56"), (dim=3|id=771|"Link,l=57"), (dim=2|id=389|"S=1/2,Site,n=57")', (dim=2|id=389|"S=1/2,Site,n=57"))
# [58] ((dim=3|id=771|"Link,l=57"), (dim=3|id=246|"Link,l=58"), (dim=2|id=658|"S=1/2,Site,n=58")', (dim=2|id=658|"S=1/2,Site,n=58"))
# [59] ((dim=3|id=246|"Link,l=58"), (dim=3|id=125|"Link,l=59"), (dim=2|id=39|"S=1/2,Site,n=59")', (dim=2|id=39|"S=1/2,Site,n=59"))
# [60] ((dim=3|id=125|"Link,l=59"), (dim=3|id=449|"Link,l=60"), (dim=2|id=491|"S=1/2,Site,n=60")', (dim=2|id=491|"S=1/2,Site,n=60"))
# [61] ((dim=3|id=449|"Link,l=60"), (dim=3|id=928|"Link,l=61"), (dim=2|id=170|"S=1/2,Site,n=61")', (dim=2|id=170|"S=1/2,Site,n=61"))
# [62] ((dim=3|id=928|"Link,l=61"), (dim=3|id=609|"Link,l=62"), (dim=2|id=572|"S=1/2,Site,n=62")', (dim=2|id=572|"S=1/2,Site,n=62"))
# [63] ((dim=3|id=609|"Link,l=62"), (dim=3|id=551|"Link,l=63"), (dim=2|id=809|"S=1/2,Site,n=63")', (dim=2|id=809|"S=1/2,Site,n=63"))
# [64] ((dim=3|id=551|"Link,l=63"), (dim=3|id=670|"Link,l=64"), (dim=2|id=838|"S=1/2,Site,n=64")', (dim=2|id=838|"S=1/2,Site,n=64"))
# [65] ((dim=3|id=670|"Link,l=64"), (dim=3|id=207|"Link,l=65"), (dim=2|id=630|"S=1/2,Site,n=65")', (dim=2|id=630|"S=1/2,Site,n=65"))
# [66] ((dim=3|id=207|"Link,l=65"), (dim=3|id=397|"Link,l=66"), (dim=2|id=143|"S=1/2,Site,n=66")', (dim=2|id=143|"S=1/2,Site,n=66"))
# [67] ((dim=3|id=397|"Link,l=66"), (dim=3|id=656|"Link,l=67"), (dim=2|id=159|"S=1/2,Site,n=67")', (dim=2|id=159|"S=1/2,Site,n=67"))
# [68] ((dim=3|id=656|"Link,l=67"), (dim=3|id=339|"Link,l=68"), (dim=2|id=722|"S=1/2,Site,n=68")', (dim=2|id=722|"S=1/2,Site,n=68"))
# [69] ((dim=3|id=339|"Link,l=68"), (dim=3|id=494|"Link,l=69"), (dim=2|id=446|"S=1/2,Site,n=69")', (dim=2|id=446|"S=1/2,Site,n=69"))
# [70] ((dim=3|id=494|"Link,l=69"), (dim=3|id=279|"Link,l=70"), (dim=2|id=69|"S=1/2,Site,n=70")', (dim=2|id=69|"S=1/2,Site,n=70"))
# [71] ((dim=3|id=279|"Link,l=70"), (dim=3|id=727|"Link,l=71"), (dim=2|id=67|"S=1/2,Site,n=71")', (dim=2|id=67|"S=1/2,Site,n=71"))
# [72] ((dim=3|id=727|"Link,l=71"), (dim=3|id=920|"Link,l=72"), (dim=2|id=554|"S=1/2,Site,n=72")', (dim=2|id=554|"S=1/2,Site,n=72"))
# [73] ((dim=3|id=920|"Link,l=72"), (dim=3|id=990|"Link,l=73"), (dim=2|id=62|"S=1/2,Site,n=73")', (dim=2|id=62|"S=1/2,Site,n=73"))
# [74] ((dim=3|id=990|"Link,l=73"), (dim=3|id=980|"Link,l=74"), (dim=2|id=754|"S=1/2,Site,n=74")', (dim=2|id=754|"S=1/2,Site,n=74"))
# [75] ((dim=3|id=980|"Link,l=74"), (dim=3|id=663|"Link,l=75"), (dim=2|id=822|"S=1/2,Site,n=75")', (dim=2|id=822|"S=1/2,Site,n=75"))
# [76] ((dim=3|id=663|"Link,l=75"), (dim=3|id=880|"Link,l=76"), (dim=2|id=533|"S=1/2,Site,n=76")', (dim=2|id=533|"S=1/2,Site,n=76"))
# [77] ((dim=3|id=880|"Link,l=76"), (dim=3|id=372|"Link,l=77"), (dim=2|id=294|"S=1/2,Site,n=77")', (dim=2|id=294|"S=1/2,Site,n=77"))
# [78] ((dim=3|id=372|"Link,l=77"), (dim=3|id=75|"Link,l=78"), (dim=2|id=655|"S=1/2,Site,n=78")', (dim=2|id=655|"S=1/2,Site,n=78"))
# [79] ((dim=3|id=75|"Link,l=78"), (dim=3|id=830|"Link,l=79"), (dim=2|id=327|"S=1/2,Site,n=79")', (dim=2|id=327|"S=1/2,Site,n=79"))
# [80] ((dim=3|id=830|"Link,l=79"), (dim=3|id=18|"Link,l=80"), (dim=2|id=824|"S=1/2,Site,n=80")', (dim=2|id=824|"S=1/2,Site,n=80"))
# [81] ((dim=3|id=18|"Link,l=80"), (dim=3|id=92|"Link,l=81"), (dim=2|id=391|"S=1/2,Site,n=81")', (dim=2|id=391|"S=1/2,Site,n=81"))
# [82] ((dim=3|id=92|"Link,l=81"), (dim=3|id=405|"Link,l=82"), (dim=2|id=732|"S=1/2,Site,n=82")', (dim=2|id=732|"S=1/2,Site,n=82"))
# [83] ((dim=3|id=405|"Link,l=82"), (dim=3|id=108|"Link,l=83"), (dim=2|id=768|"S=1/2,Site,n=83")', (dim=2|id=768|"S=1/2,Site,n=83"))
# [84] ((dim=3|id=108|"Link,l=83"), (dim=3|id=146|"Link,l=84"), (dim=2|id=978|"S=1/2,Site,n=84")', (dim=2|id=978|"S=1/2,Site,n=84"))
# [85] ((dim=3|id=146|"Link,l=84"), (dim=3|id=254|"Link,l=85"), (dim=2|id=805|"S=1/2,Site,n=85")', (dim=2|id=805|"S=1/2,Site,n=85"))
# [86] ((dim=3|id=254|"Link,l=85"), (dim=3|id=869|"Link,l=86"), (dim=2|id=404|"S=1/2,Site,n=86")', (dim=2|id=404|"S=1/2,Site,n=86"))
# [87] ((dim=3|id=869|"Link,l=86"), (dim=3|id=330|"Link,l=87"), (dim=2|id=377|"S=1/2,Site,n=87")', (dim=2|id=377|"S=1/2,Site,n=87"))
# [88] ((dim=3|id=330|"Link,l=87"), (dim=3|id=122|"Link,l=88"), (dim=2|id=33|"S=1/2,Site,n=88")', (dim=2|id=33|"S=1/2,Site,n=88"))
# [89] ((dim=3|id=122|"Link,l=88"), (dim=3|id=830|"Link,l=89"), (dim=2|id=658|"S=1/2,Site,n=89")', (dim=2|id=658|"S=1/2,Site,n=89"))
# [90] ((dim=3|id=830|"Link,l=89"), (dim=3|id=810|"Link,l=90"), (dim=2|id=733|"S=1/2,Site,n=90")', (dim=2|id=733|"S=1/2,Site,n=90"))
# [91] ((dim=3|id=810|"Link,l=90"), (dim=3|id=217|"Link,l=91"), (dim=2|id=435|"S=1/2,Site,n=91")', (dim=2|id=435|"S=1/2,Site,n=91"))
# [92] ((dim=3|id=217|"Link,l=91"), (dim=3|id=163|"Link,l=92"), (dim=2|id=871|"S=1/2,Site,n=92")', (dim=2|id=871|"S=1/2,Site,n=92"))
# [93] ((dim=3|id=163|"Link,l=92"), (dim=3|id=76|"Link,l=93"), (dim=2|id=742|"S=1/2,Site,n=93")', (dim=2|id=742|"S=1/2,Site,n=93"))
# [94] ((dim=3|id=76|"Link,l=93"), (dim=3|id=621|"Link,l=94"), (dim=2|id=263|"S=1/2,Site,n=94")', (dim=2|id=263|"S=1/2,Site,n=94"))
# [95] ((dim=3|id=621|"Link,l=94"), (dim=3|id=860|"Link,l=95"), (dim=2|id=111|"S=1/2,Site,n=95")', (dim=2|id=111|"S=1/2,Site,n=95"))
# [96] ((dim=3|id=860|"Link,l=95"), (dim=3|id=437|"Link,l=96"), (dim=2|id=312|"S=1/2,Site,n=96")', (dim=2|id=312|"S=1/2,Site,n=96"))
# [97] ((dim=3|id=437|"Link,l=96"), (dim=3|id=59|"Link,l=97"), (dim=2|id=979|"S=1/2,Site,n=97")', (dim=2|id=979|"S=1/2,Site,n=97"))
# [98] ((dim=3|id=59|"Link,l=97"), (dim=3|id=322|"Link,l=98"), (dim=2|id=3|"S=1/2,Site,n=98")', (dim=2|id=3|"S=1/2,Site,n=98"))
# [99] ((dim=3|id=322|"Link,l=98"), (dim=3|id=893|"Link,l=99"), (dim=2|id=547|"S=1/2,Site,n=99")', (dim=2|id=547|"S=1/2,Site,n=99"))
# [100] ((dim=3|id=893|"Link,l=99"), (dim=2|id=583|"S=1/2,Site,n=100")', (dim=2|id=583|"S=1/2,Site,n=100"))

# %%
# State Initialization
psi = randomMPS(sites, 10)
xi, lmd = [rand(-0.1:0.01:0.1), rand(0.0:0.1:0.5)]
_sz,_sx,_sx2 = spin_averages(psi)
# Out:
# (0.4950409242085722, -0.5644544996687871, 25.02810756299707)

# %%
# Loop in g
g_list = range(0, 1.0, length=20)
E0_list = Float64[]
avg_n_list = Float64[]
avg_sz_list = Float64[]
for g in g_list
    K = (4.0*g^2)/(N*omega)
    # Loop Initialization
    max_iter = 500
    prev_E0 = Inf
    E0 = 0.0
    for iter in 1:max_iter
        # check convergence
        if abs(E0-prev_E0) < 1e-8
            println("for g=$g, converged at step $iter")
            break
        end
        println("step $iter: energy difference = $(abs(E0-prev_E0))")
        prev_E0 = E0
        
        # Built the effective spin Hamiltonian
        eta = (2.0/N)*exp(-2.0*xi)*(lmd*g/omega)^2
        H_eff = eps*exp(-eta)*Sz - 2.0*K*((1-lmd)^2)*_sx*Sx + K*(lmd^2 - 2.0*lmd)*Sx2
        
        # Run DMRG
        obs = DMRGObserver(energy_tol=1e-8, minsweeps=20)
        _, psi = dmrg(H_eff, psi; nsweeps=500, maxdim=[20,50,100,250], cutoff=[1e-8], observer=obs, outputlevel=1)
    
        # Update spin averages
        _sz,_sx,_sx2 = spin_averages(psi)
        
        # Optimize Variational Parameters
        cost_func(x) = energy_cost([omega, eps, g, N], x, [_sz,_sx,_sx2])
        res = optimize(cost_func, [xi,lmd], LBFGS(), Optim.Options(iterations=100))
        xi,lmd = Optim.minimizer(res)
        E0 = Optim.minimum(res)
    end
    # Save converged observables
    eta = (2.0/N)*exp(-2.0*xi)*(lmd*g/omega)^2
    Komg = (4.0*g^2)/(N*omega^2)
    _sz,_sx,_sx2 = spin_averages(psi)
    
    # Observables
    avg_n = sinh(xi)^2 + Komg*(1-lmd^2)*_sx^2 + Komg*_sx2*lmd^2
    avg_sz = exp(-eta)*_sz

    push!(E0_list, E0/N)
    push!(avg_n_list, avg_n/N)
    push!(avg_sz_list, avg_sz/N)
end
# Out:
# step 1: energy difference = Inf
# After sweep 1 energy=-49.981126162265674  maxlinkdim=19 maxerr=9.98E-09 time=0.065
# After sweep 2 energy=-49.999986062854006  maxlinkdim=4 maxerr=9.97E-09 time=0.038
# After sweep 3 energy=-50.00000000000045  maxlinkdim=1 maxerr=3.13E-09 time=0.022
# After sweep 4 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.019
# After sweep 5 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.020
# After sweep 6 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.019
# After sweep 7 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 8 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.019
# After sweep 9 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.018
# After sweep 10 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.015
# After sweep 11 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.018
# After sweep 12 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.019
# After sweep 13 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.015
# After sweep 14 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.019
# After sweep 15 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.019
# After sweep 16 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.016
# After sweep 17 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.019
# After sweep 18 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.019
# After sweep 19 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.016
# After sweep 20 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.015
# After sweep 21 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# Energy difference less than 1.0e-8, stopping DMRG
# step 2: energy difference = 50.0
# After sweep 1 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.019
# After sweep 2 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 3 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.015
# After sweep 4 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.016
# After sweep 5 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.016
# After sweep 6 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.014
# After sweep 7 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.016
# After sweep 8 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.016
# After sweep 9 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.014
# After sweep 10 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 11 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 12 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.014
# After sweep 13 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 14 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 15 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 16 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.015
# After sweep 17 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 18 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 19 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.015
# After sweep 20 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 21 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.016
# Energy difference less than 1.0e-8, stopping DMRG
# converged at step 3
# step 1: energy difference = Inf
# After sweep 1 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 2 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.015
# After sweep 3 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 4 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.016
# After sweep 5 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.016
# After sweep 6 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.015
# After sweep 7 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.016
# After sweep 8 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 9 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.015
# After sweep 10 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 11 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 12 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.015
# After sweep 13 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 14 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 15 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.015
# After sweep 16 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 17 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 18 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.015
# After sweep 19 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.017
# After sweep 20 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.016
# After sweep 21 energy=-50.00000000000045  maxlinkdim=1 maxerr=0.00E+00 time=0.015
# Energy difference less than 1.0e-8, stopping DMRG
# step 2: energy difference = 50.00138552593193
# After sweep 1 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.025
# After sweep 2 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.024
# After sweep 3 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.023
# After sweep 4 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.023
# After sweep 5 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.023
# After sweep 6 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.023
# After sweep 7 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.023
# After sweep 8 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.023
# After sweep 9 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.023
# After sweep 10 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.023
# After sweep 11 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.023
# After sweep 12 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.023
# After sweep 13 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.023
# After sweep 14 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.023
# After sweep 15 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.023
# After sweep 16 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.023
# After sweep 17 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.025
# After sweep 18 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.023
# After sweep 19 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0.025
# After sweep 20 energy=-50.00138600637653  maxlinkdim=1 maxerr=4.32E-10 time=0
maxlinkdim=2 maxerr=6.22E-09 time=0.029
# After sweep 20 energy=-50.05857986279753  maxlinkdim=2 maxerr=6.22E-09 time=0.027
# After sweep 21 energy=-50.058579862797984  maxlinkdim=2 maxerr=6.22E-09 time=0.029
# Energy difference less than 1.0e-8, stopping DMRG
# converged at step 5
# step 1: energy difference = Inf
# After sweep 1 energy=-50.08478269398228  maxlinkdim=3 maxerr=9.79E-09 time=0.027
# After sweep 2 energy=-50.084782818016556  maxlinkdim=3 maxerr=2.77E-10 time=0.030
# After sweep 3 energy=-50.084782818018105  maxlinkdim=3 maxerr=2.77E-10 time=0.029
# After sweep 4 energy=-50.08478281801796  maxlinkdim=3 maxerr=2.77E-10 time=0.028
# After sweep 5 energy=-50.08478281801781  maxlinkdim=3 maxerr=2.77E-10 time=0.028
# After sweep 6 energy=-50.08478281801806  maxlinkdim=3 maxerr=2.77E-10 time=0.028
# After sweep 7 energy=-50.08478281801818  maxlinkdim=3 maxerr=2.77E-10 time=0.028
# After sweep 8 energy=-50.08478281801794  maxlinkdim=3 maxerr=2.77E-10 time=0.029
# After sweep 9 energy=-50.0847828180179  maxlinkdim=3 maxerr=2.77E-10 time=0.030
# After sweep 10 energy=-50.084782818018006  maxlinkdim=3 maxerr=2.77E-10 time=0.030
# After sweep 11 energy=-50.08478281801779  maxlinkdim=3 maxerr=2.77E-10 time=0.030
# After sweep 12 energy=-50.084782818017864  maxlinkdim=3 maxerr=2.77E-10 time=0.029
# After sweep 13 energy=-50.0847828180178  maxlinkdim=3 maxerr=2.77E-10 time=0.031
# After sweep 14 energy=-50.08478281801807  maxlinkdim=3 maxerr=2.77E-10 time=0.031
# After sweep 15 energy=-50.084782818017885  maxlinkdim=3 maxerr=2.77E-10 time=0.031
# After sweep 16 energy=-50.08478281801796  maxlinkdim=3 maxerr=2.77E-10 time=0.031
# After sweep 17 energy=-50.08478281801803  maxlinkdim=3 maxerr=2.77E-10 time=0.030
# After sweep 18 energy=-50.08478281801779  maxlinkdim=3 maxerr=2.77E-10 time=0.031
# After sweep 19 energy=-50.08478281801795  maxlinkdim=3 maxerr=2.77E-10 time=0.030
# After sweep 20 energy=-50.08478281801796  maxlinkdim=3 maxerr=2.77E-10 time=0.029
# After sweep 21 energy=-50.08478281801792  maxlinkdim=3 maxerr=2.77E-10 time=0.031
# Energy difference less than 1.0e-8, stopping DMRG
# step 2: energy difference = 50.08426185739763
# After sweep 1 energy=-50.086180243033354  maxlinkdim=3 maxerr=3.48E-10 time=0.027
# After sweep 2 energy=-50.08618024303933  maxlinkdim=3 maxerr=3.48E-10 time=0.027
# After sweep 3 energy=-50.086180243038946  maxlinkdim=3 maxerr=3.48E-10 time=0.029
# After sweep 4 energy=-50.08618024303922  maxlinkdim=3 maxerr=3.48E-10 time=0.029
# After sweep 5 energy=-50.08618024303925  maxlinkdim=3 maxerr=3.48E-10 time=0.029
# After sweep 6 energy=-50.08618024303933  maxlinkdim=3 maxerr=3.48E-10 time=0.029
# After sweep 7 energy=-50.08618024303942  maxlinkdim=3 maxerr=3.48E-10 time=0.032
# After sweep 8 energy=-50.08618024303916  maxlinkdim=3 maxerr=3.48E-10 time=0.029
# After sweep 9 energy=-50.08618024303931  maxlinkdim=3 maxerr=3.48E-10 time=0.029
# After sweep 10 energy=-50.08618024303936  maxlinkdim=3 maxerr=3.48E-10 time=0.028
# After sweep 11 energy=-50.08618024303952  maxlinkdim=3 maxerr=3.48E-10 time=0.031
# After sweep 12 energy=-50.086180243039266  maxlinkdim=3 maxerr=3.48E-10 time=0.029
# After sweep 13 energy=-50.08618024303915  maxlinkdim=3 maxerr=3.48E-10 time=0.029
# After sweep 14 energy=-50.08618024303937  maxlinkdim=3 maxerr=3.48E-10 time=0.029
# After sweep 15 energy=-50.08618024303944  maxlinkdim=3 maxerr=3.48E-10 time=0.029
# After sweep 16 energy=-50.08618024303948  maxlinkdim=3 maxerr=3.48E-10 time=0.029
# After sweep 17 energy=-50.08618024303919  maxlinkdim=3 maxerr=3.48E-10 time=0.029
# After sweep 18 energy=-50.08618024303951  maxlinkdim=3 maxerr=3.48E-10 time=0.029
# After sweep 19 energy=-50.086180243039244  maxlinkdim=3 maxerr=3.48E-10 time=0.029
# After sweep 20 energy=-50.08618024303922  maxlinkdim=3 maxerr=3.48E-10 time=0.029
# After sweep 21 energy=-50.08618024303942  maxlinkdim=3 maxerr=3.48E-10 time=0.032
# Energy difference less than 1.0e-8, stopping DMRG
# step 3: energy difference = 2.9900062777699077e-5
# After sweep 1 energy=-50.086219656647245  maxlinkdim=3 maxerr=3.56E-10 time=0.028
# After sweep 2 energy=-50.08621965664763  maxlinkdim=3 maxerr=3.56E-10 time=0.029
# After sweep 3 energy=-50.086219656647444  maxlinkdim=3 maxerr=3.56E-10 time=0.030
# After sweep 4 energy=-50.08621965664744  maxlinkdim=3 maxerr=3.56E-10 time=0.030
# After sweep 5 energy=-50.08621965664722  maxlinkdim=3 maxerr=3.56E-10 time=0.030
# After sweep 6 energy=-50.086219656647124  maxlinkdim=3 maxerr=3.56E-10 time=0.030
# After sweep 7 energy=-50.0862196566472  maxlinkdim=3 maxerr=3.56E-10 time=0.030
# After sweep 8 energy=-50.08621965664727  maxlinkdim=3 maxerr=3.56E-10 time=0.029
# After sweep 9 energy=-50.08621965664744  maxlinkdim=3 maxerr=3.56E-10 time=0.029
# After sweep 10 energy=-50.08621965664716  maxlinkdim=3 maxerr=3.56E-10 time=0.030
# After sweep 11 energy=-50.086219656647245  maxlinkdim=3 maxerr=3.56E-10 time=0.032
# After sweep 12 energy=-50.086219656647074  maxlinkdim=3 maxerr=3.56E-10 time=0.028
# After sweep 13 energy=-50.08621965664728  maxlinkdim=3 maxerr=3.56E-10 time=0.028
# After sweep 14 energy=-50.08621965664706  maxlinkdim=3 maxerr=3.56E-10 time=0.029
# After sweep 15 energy=-50.08621965664727  maxlinkdim=3 maxerr=3.56E-10 time=0.030
# After sweep 16 energy=-50.086219656647266  maxlinkdim=3 maxerr=3.56E-10 time=0.030
# After sweep 17 energy=-50.086219656647216  maxlinkdim=3 maxerr=3.56E-10 time=0.030
# After sweep 18 energy=-50.08621965664701  maxlinkdim=3 maxerr=3.56E-10 time=0.029
# After sweep 19 energy=-50.086219656647046  maxlinkdim=3 maxerr=3.56E-10 time=0.030
# After sweep 20 energy=-50.08621965664716  maxlinkdim=3 maxerr=3.56E-10 time=0.030
# After sweep 21 energy=-50.086219656647344  maxlinkdim=3 maxerr=3.56E-10 time=0.029
# Energy difference less than 1.0e-8, stopping DMRG
# step 4: energy difference = 3.0611624168841445e-7
# After sweep 1 energy=-50.08622339314138  maxlinkdim=3 maxerr=3.57E-10 time=0.032
# After sweep 2 energy=-50.086223393141196  maxlinkdim=3 maxerr=3.57E-10 time=0.029
# After sweep 3 energy=-50.08622339314139  maxlinkdim=3 maxerr=3.57E-10 time=0.029
# After sweep 4 energy=-50.08622339314151  maxlinkdim=3 maxerr=3.57E-10 time=0.030
# After sweep 5 energy=-50.08622339314142  maxlinkdim=3 maxerr=3.57E-10 time=0.030
# After sweep 6 energy=-50.086223393141275  maxlinkdim=3 maxerr=3.57E-10 time=0.030
# After sweep 7 energy=-50.08622339314127  maxlinkdim=3 maxerr=3.57E-10 time=0.029
# After sweep 8 energy=-50.08622339314152  maxlinkdim=3 maxerr=3.57E-10 time=0.029
# After sweep 9 energy=-50.08622339314154  maxlinkdim=3 maxerr=3.57E-10 time=0.030
# After sweep 10 energy=-50.08622339314132  maxlinkdim=3 maxerr=3.57E-10 time=0.029
# After sweep 11 energy=-50.08622339314135  maxlinkdim=3 maxerr=3.57E-10 time=0.029
# After sweep 12 energy=-50.08622339314144  maxlinkdim=3 maxerr=3.57E-10 time=0.029
# After sweep 13 energy=-50.08622339314144  maxlinkdim=3 maxerr=3.57E-10 time=0.033
# After sweep 14 energy=-50.08622339314165  maxlinkdim=3 maxerr=3.57E-10 time=0.030
# After sweep 15 energy=-50.08622339314113  maxlinkdim=3 maxerr=3.57E-10 time=0.031
# After sweep 16 energy=-50.086223393141324  maxlinkdim=3 maxerr=3.57E-10 time=0.032
# After sweep 17 energy=-50.08622339314125  maxlinkdim=3 maxerr=3.57E-10 time=0.031
# After sweep 18 energy=-50.086223393141175  maxlinkdim=3 maxerr=3.57E-10 time=0.031
# After sweep 19 energy=-50.08622339314156  maxlinkdim=3 maxerr=3.57E-10 time=0.030
# After sweep 20 energy=-50.08622339314156  maxlinkdim=3 maxerr=3.57E-10 time=0.032
# After sweep 21 energy=-50.08622339314139  maxlinkdim=3 maxerr=3.57E-10 time=0.030
# Energy difference less than 1.0e-8, stopping DMRG
# converged at step 5
# step 1: energy difference = Inf
# After sweep 1 energy=-50.12278396020098  maxlinkdim=3 maxerr=2.87E-09 time=0.029
# After sweep 2 energy=-50.1227839610987  maxlinkdim=3 maxerr=2.88E-09 time=0.031
# After sweep 3 energy=-50.122783961098285  maxlinkdim=3 maxerr=2.88E-09 time=0.032
# After sweep 4 energy=-50.12278396109859  maxlinkdim=3 maxerr=2.88E-09 time=0.032
# After sweep 5 energy=-50.12278396109827  maxlinkdim=3 maxerr=2.88E-09 time=0.034
# After sweep 6 energy=-50.12278396109843  maxlinkdim=3 maxerr=2.88E-09 time=0.036
# After sweep 7 energy=-50.1227839610985  maxlinkdim=3 maxerr=2.88E-09 time=0.049
# After sweep 8 energy=-50.122783961098506  maxlinkdim=3 maxerr=2.88E-09 time=0.070
# After sweep 9 energy=-50.12278396109857  maxlinkdim=3 maxerr=2.88E-09 time=0.041
maxlinkdim=2 maxerr=1.22E-13 time=0.028
# After sweep 8 energy=-165.35383031735404  maxlinkdim=2 maxerr=1.22E-13 time=0.031
# After sweep 9 energy=-165.35383031735336  maxlinkdim=2 maxerr=1.22E-13 time=0.028
# After sweep 10 energy=-165.35383031735373  maxlinkdim=2 maxerr=1.22E-13 time=0.028
# After sweep 11 energy=-165.35383031735373  maxlinkdim=2 maxerr=1.22E-13 time=0.028
# After sweep 12 energy=-165.3538303173542  maxlinkdim=2 maxerr=1.22E-13 time=0.029
# After sweep 13 energy=-165.35383031735395  maxlinkdim=2 maxerr=1.22E-13 time=0.029
# After sweep 14 energy=-165.35383031735424  maxlinkdim=2 maxerr=1.22E-13 time=0.029
# After sweep 15 energy=-165.35383031735444  maxlinkdim=2 maxerr=1.22E-13 time=0.028
# After sweep 16 energy=-165.3538303173541  maxlinkdim=2 maxerr=1.22E-13 time=0.031
# After sweep 17 energy=-165.35383031735418  maxlinkdim=2 maxerr=1.22E-13 time=0.029
# After sweep 18 energy=-165.35383031735475  maxlinkdim=2 maxerr=1.22E-13 time=0.028
# After sweep 19 energy=-165.35383031735375  maxlinkdim=2 maxerr=1.22E-13 time=0.028
# After sweep 20 energy=-165.35383031735418  maxlinkdim=2 maxerr=1.22E-13 time=0.029
# After sweep 21 energy=-165.35383031735464  maxlinkdim=2 maxerr=1.22E-13 time=0.029
# Energy difference less than 1.0e-8, stopping DMRG
# step 4: energy difference = 2.729388199895766e-7
# After sweep 1 energy=-165.36200817975845  maxlinkdim=2 maxerr=1.22E-13 time=0.031
# After sweep 2 energy=-165.36200817975813  maxlinkdim=2 maxerr=1.21E-13 time=0.032
# After sweep 3 energy=-165.36200817975867  maxlinkdim=2 maxerr=1.22E-13 time=0.034
# After sweep 4 energy=-165.3620081797589  maxlinkdim=2 maxerr=1.22E-13 time=0.034
# After sweep 5 energy=-165.36200817975921  maxlinkdim=2 maxerr=1.22E-13 time=0.031
# After sweep 6 energy=-165.36200817975913  maxlinkdim=2 maxerr=1.22E-13 time=0.033
# After sweep 7 energy=-165.362008179759  maxlinkdim=2 maxerr=1.22E-13 time=0.031
# After sweep 8 energy=-165.36200817975867  maxlinkdim=2 maxerr=1.22E-13 time=0.031
# After sweep 9 energy=-165.3620081797589  maxlinkdim=2 maxerr=1.22E-13 time=0.031
# After sweep 10 energy=-165.36200817975902  maxlinkdim=2 maxerr=1.21E-13 time=0.031
# After sweep 11 energy=-165.36200817975893  maxlinkdim=2 maxerr=1.21E-13 time=0.030
# After sweep 12 energy=-165.36200817975867  maxlinkdim=2 maxerr=1.22E-13 time=0.031
# After sweep 13 energy=-165.36200817975833  maxlinkdim=2 maxerr=1.22E-13 time=0.034
# After sweep 14 energy=-165.36200817975828  maxlinkdim=2 maxerr=1.22E-13 time=0.030
# After sweep 15 energy=-165.3620081797584  maxlinkdim=2 maxerr=1.22E-13 time=0.030
# After sweep 16 energy=-165.36200817975845  maxlinkdim=2 maxerr=1.22E-13 time=0.030
# After sweep 17 energy=-165.36200817975825  maxlinkdim=2 maxerr=1.22E-13 time=0.030
# After sweep 18 energy=-165.36200817975788  maxlinkdim=2 maxerr=1.22E-13 time=0.030
# After sweep 19 energy=-165.36200817975853  maxlinkdim=2 maxerr=1.22E-13 time=0.029
# After sweep 20 energy=-165.36200817975887  maxlinkdim=2 maxerr=1.21E-13 time=0.031
# After sweep 21 energy=-165.36200817975777  maxlinkdim=2 maxerr=1.22E-13 time=0.029
# Energy difference less than 1.0e-8, stopping DMRG
# converged at step 5

# %%
using PyPlot
using LaTeXStrings

# %%
fig, ax = subplots(1, 3, figsize=(14, 4), sharex=true)

ax[1].plot(g_list, E0_list, marker="o", markersize=4, color="tab:brown")
ax[2].plot(g_list, avg_n_list, marker="o", markersize=4, color="tab:blue")
ax[3].plot(g_list, avg_sz_list, marker="o", markersize=4, color="tab:red")

ax[1].set_ylabel(L"$E_0/N$")
ax[2].set_ylabel(L"$\langle n \rangle/N$")
ax[3].set_ylabel(L"$\langle S^z \rangle/N$")

for axi in ax
    axi.set_xlabel(L"$g$")
    axi.axvline(x=0.5, ls="--", color="gray", alpha=0.6)
end

ax[1].set_xlim(0, 1)
ax[2].set_ylim(bottom=0)
ax[3].set_ylim(-0.5, 0)

fig.tight_layout()
# Out:
# Figure(PyObject <Figure size 1400x400 with 3 Axes>)
